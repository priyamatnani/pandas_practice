# %% [markdown]
# ### A series object should have the same data type throughout

# %%
arr = ["page","abb","nop","pop"]

# %%
import pandas as pd

# %%
pd.Series(arr)
# Out:
# 0    page
# 1     abb
# 2     nop
# 3     pop
# dtype: object

# %%
dict = {
    "A" : "apple",
    "B" : "ball",
    "C" : "cat"
}

# %%
pd_dict = pd.Series(dict)
pd_dict
# Out:
# A    apple
# B     ball
# C      cat
# dtype: object

# %%
pd_dict['A']
# Out:
# 'apple'

# %% [markdown]
# ### A Series is a combination of both a python dict and a list

# %%
pd_dict.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of A    apple
# B     ball
# C      cat
# dtype: object>

# %%
pd.Series(arr).values
# Out:
# array(['page', 'abb', 'nop', 'pop'], dtype=object)

# %%
pd_dict.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
pd.Series(arr).index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
pd_dict.dtypes
# Out:
# dtype('O')

# %%
pd_dict.sum()
# Out:
# 'appleballcat'

# %%
nums = pd.Series([1,2,3,4])

# %%
nums.sum()
# Out:
# 10

# %%
nums.product()
# Out:
# 24

# %%
nums.mean()
# Out:
# 2.5

# %%
data = [20,10,4,30]
index = ['a','b','c','c']

x = pd.Series(data,index=index)

# %% [markdown]
# ### The index labels in a pandas series do not have to be unique

# %%
x.c
# Out:
# c     4
# c    30
# dtype: int64

# %% [markdown]
# ## Import file using read.csv

# %%
pd.read_csv(filepath_or_buffer="data/pokemon.csv" )
# Out:
#         Pokemon      Type
# 0     Bulbasaur     Grass
# 1       Ivysaur     Grass
# 2      Venusaur     Grass
# 3    Charmander      Fire
# 4    Charmeleon      Fire
# 5     Charizard      Fire
# 6      Squirtle     Water
# 7     Wartortle     Water
# 8     Blastoise     Water
# 9      Caterpie       Bug
# 10      Metapod       Bug
# 11   Butterfree       Bug
# 12       Weedle       Bug
# 13       Kakuna       Bug
# 14     Beedrill       Bug
# 15       Pidgey    Normal
# 16    Pidgeotto    Normal
# 17      Pidgeot    Normal
# 18      Rattata    Normal
# 19     Raticate    Normal
# 20      Spearow    Normal
# 21       Fearow    Normal
# 22        Ekans    Poison
# 23        Arbok    Poison
# 24      Pikachu  Electric
# 25       Raichu  Electric
# 26    Sandshrew    Ground
# 27    Sandslash    Ground
# 28      Nidoran    Poison
# 29     Nidorina    Poison
# ..          ...       ...
# 691   Clauncher     Water
# 692   Clawitzer     Water
# 693  Helioptile  Electric
# ...

# %% [markdown]
# ### the usecols param in read_csv allows to select only certain columns that will be useful.
# squeeze param allows to keep the data in the form of a Series instead of the default conversion into a DF

# %%
pokemon = pd.read_csv(filepath_or_buffer="data/pokemon.csv" , squeeze=True, usecols=['Pokemon'])

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
google = pd.read_csv(filepath_or_buffer="data/google_stock_price.csv", squeeze=True)

# %%
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
# 5        53.90
# 6        53.02
# 7        50.95
# 8        51.13
# 9        50.07
# 10       50.70
# 11       49.95
# 12       50.74
# 13       51.10
# 14       51.10
# 15       52.61
# 16       53.70
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 21       59.62
# 22       58.86
# 23       59.13
# 24       60.35
# 25       59.86
# 26       59.07
# 27       63.37
# 28       65.47
# 29       64.74
#          ...
# 2982    675.22
# 2983    668.26
# 2984    680.04
# 2985    684.11
# 2986    692.10
# 2987    699.21
# 2988    694.49
# 2989    697.77
# 2990    695.36
# 2991    705.63
# 2992    715.09
# 2993    720.64
# 2994    716.98
# 2995    720.95
# 2996    719.85
# 2997    733.78
# 2998    736.96
# 2999    741.19
# 3000    738.63
# 3001    742.74
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# ...

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
pokemon.head(15)
# Out:
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# 5      Charizard
# 6       Squirtle
# 7      Wartortle
# 8      Blastoise
# 9       Caterpie
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# Name: Pokemon, dtype: object

# %% [markdown]
# ### all python functions work on the Series object

# %%
len(pokemon)
# Out:
# 721

# %%
sum(google)
# Out:
# 1006942.0000000002

# %%
# this gives all the functions that work on this. even the hidden ones
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
max(google)
# Out:
# 782.22000000000003

# %%
pokemon.values
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon',
#        'Charizard', 'Squirtle', 'Wartortle', 'Blastoise', 'Caterpie',
#        'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill', 'Pidgey',
#        'Pidgeotto', 'Pidgeot', 'Rattata', 'Raticate', 'Spearow', 'Fearow',
#        'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash',
#        'Nidoran', 'Nidorina', 'Nidoqueen', 'Nidoran♂', 'Nidorino',
#        'Nidoking', 'Clefairy', 'Clefable', 'Vulpix', 'Ninetales',
#        'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom',
#        'Vileplume', 'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett',
#        'Dugtrio', 'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey',
#        'Primeape', 'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl',
#        'Poliwrath', 'Abra', 'Kadabra', 'Alakazam', 'Machop', 'Machoke',
#        'Machamp', 'Bellsprout', 'Weepinbell', 'Victreebel', 'Tentacool',
# ...

# %%
nums.is_unique
# Out:
# True

# %%
pokemon.is_unique
# Out:
# True

# %%
pokemon.shape
# Out:
# (721,)

# %% [markdown]
# size of the dataframe - total number of cells

# %%
pokemon.size
# Out:
# 721

# %%
pokemon.sort_values().head()
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
# Name: Pokemon, dtype: object

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %% [markdown]
# ## Sorted returns a list whereas sort_values will give an object

# %%
pokemon.sort_values(inplace=True)

# %%
pokemon.head(5)
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
# Name: Pokemon, dtype: object
