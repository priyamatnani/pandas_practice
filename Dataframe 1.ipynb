# %%
import pandas as pd

# %%
nba = pd.read_csv('data/nba.csv')

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %% [markdown]
# Pandas is converting all the numbers to float because there are NaNs in these rows. It does this always when it finds NaN values. The original data consisted of integers and not floats

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.head().values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, 'PG', 25.0, '6-2', 180.0,
#         'Texas', 7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, 'SF', 25.0, '6-6', 235.0,
#         'Marquette', 6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, 'SG', 27.0, '6-5', 205.0,
#         'Boston University', nan],
#        ['R.J. Hunter', 'Boston Celtics', 28.0, 'SG', 22.0, '6-5', 185.0,
#         'Georgia State', 1148640.0],
#        ['Jonas Jerebko', 'Boston Celtics', 8.0, 'PF', 29.0, '6-10', 231.0,
#         nan, 5000000.0]], dtype=object)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# Strings are called as objects in pandas

# %%
nba.sum(axis="columns")
# Out:
# 0       7730542.0
# 1       6796476.0
# 2           262.0
# 3       1148875.0
# 4       5000268.0
# 5      12000359.0
# 6       1171271.0
# 7       2165464.0
# 8       1824584.0
# 9       3431318.0
# 10      2569551.0
# 11      6913085.0
# 12      3425768.0
# 13      1750088.0
# 14      2617298.0
# 15      3425797.0
# 16       845295.0
# 17      1500249.0
# 18      1335745.0
# 19      6300234.0
# 20      1600080.0
# 21       134466.0
# 22      1500198.0
# 23     19689314.0
# 24      1140462.0
# 25       947555.0
# 26       981651.0
# 27       947564.0
# 28       947524.0
# 29     11236233.0
#           ...
# 428     8043143.0
# 429      625327.0
# 430      947533.0
# 431     6981086.0
# 432     2894301.0
# 433     6000252.0
# 434     5016334.0
# 435     3076160.0
# 436     4236507.0
# 437     2525387.0
# 438      525345.0
# 439     1415805.0
# 440     2855145.0
# 441     2638001.0
# 442     4775289.0
# 443     2658457.0
# 444     9463732.0
# 445     3777941.0
# 446    12000304.0
# ...

# %%
nba.sum()
# Out:
# Number    8.079000e+03
# Age       1.231100e+04
# Weight    1.012360e+05
# Salary    2.159837e+09
# dtype: float64

# %%
rev = pd.read_csv('data/revenue.csv', index_col="Date")

# %%
rev.head()
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933
# 1/4/16       730          904    885
# 1/5/16       114           71    253

# %%
nba[["Name", "Team"]]
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# ...

# %% [markdown]
# the double brackets while selecting multiple columns shows that the retirned type is a dataframe. If we just try nba["Name"] it will return a Series

# %%
nba.insert(loc=3, column="GirlFriend", value="PM")

# %%
nba.head()
# Out:
#             Name            Team  Number GirlFriend Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0         PM       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0         PM       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0         PM       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0         PM       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0         PM       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
nba["Sports"] = "ball"

# %%
nba.head(3)
# Out:
#             Name            Team  Number GirlFriend Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0         PM       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0         PM       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0         PM       SG  27.0    6-5
#
#    Weight            College     Salary Sports
# 0   180.0              Texas  7730337.0   ball
# 1   235.0          Marquette  6796117.0   ball
# 2   205.0  Boston University        NaN   ball

# %%
def test():
    return 5

# %%
nba["Number"].add(5)
# Out:
# 0        5.0
# 1      104.0
# 2       35.0
# 3       33.0
# 4       13.0
# 5       95.0
# 6       60.0
# 7       46.0
# 8       17.0
# 9       41.0
# 10      12.0
# 11       9.0
# 12      16.0
# 13      18.0
# 14      49.0
# 15      49.0
# 16      27.0
# 17      26.0
# 18      29.0
# 19       7.0
# 20      15.0
# 21      11.0
# 22       5.0
# 23      16.0
# 24       6.0
# 25      38.0
# 26      46.0
# 27      19.0
# 28      20.0
# 29      35.0
#        ...
# 428     13.0
# 429     10.0
# 430     28.0
# 431     22.0
# 432      9.0
# 433     14.0
# 434     40.0
# 435     16.0
# 436      5.0
# 437      8.0
# 438     49.0
# 439     29.0
# 440      7.0
# 441     26.0
# 442     38.0
# 443      8.0
# 444     15.0
# 445     16.0
# 446     20.0
# 447     32.0
# 448     25.0
# 449     10.0
# 450      7.0
# 451     28.0
# 452     46.0
# 453     13.0
# 454     30.0
# 455     26.0
# 456     29.0
# 457      NaN
# Name: Number, Length: 458, dtype: float64

# %% [markdown]
# Other methods include add , sub , mul , div

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.tail(3)
# Out:
#              Name       Team  Number GirlFriend Position   Age Height  Weight  \
# 455  Tibor Pleiss  Utah Jazz    21.0         PM        C  26.0    7-3   256.0
# 456   Jeff Withey  Utah Jazz    24.0         PM        C  26.0    7-0   231.0
# 457           NaN        NaN     NaN         PM      NaN   NaN    NaN     NaN
#
#     College     Salary Sports
# 455     NaN  2900000.0   ball
# 456  Kansas   947276.0   ball
# 457     NaN        NaN   ball

# %%
nba.dropna().tail(3)
# Out:
#              Name       Team  Number GirlFriend Position   Age Height  Weight  \
# 452    Trey Lyles  Utah Jazz    41.0         PM       PF  20.0   6-10   234.0
# 453  Shelvin Mack  Utah Jazz     8.0         PM       PG  26.0    6-3   203.0
# 456   Jeff Withey  Utah Jazz    24.0         PM        C  26.0    7-0   231.0
#
#       College     Salary Sports
# 452  Kentucky  2239800.0   ball
# 453    Butler  2433333.0   ball
# 456    Kansas   947276.0   ball

# %% [markdown]
# if you want to drop only those rows which have all values as NA then use how="all"

# %%
nba2 = pd.read_csv("data/nba.csv")

# %%
nba2.dropna(how="all", inplace=True)

# %%
nba2.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %% [markdown]
# dropna for with columns mentioned in the subset will remove rows which have NA only in the mentioned columns

# %%
nba2.dropna(subset=["Salary"])
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# ...

# %%
nba["Salary"].fillna(0, inplace=True)

# %%
nba.head()
# Out:
#             Name            Team  Number GirlFriend Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0         PM       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0         PM       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0         PM       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0         PM       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0         PM       PF  29.0   6-10
#
#    Weight            College     Salary Sports
# 0   180.0              Texas  7730337.0   ball
# 1   235.0          Marquette  6796117.0   ball
# 2   205.0  Boston University        0.0   ball
# 3   185.0      Georgia State  1148640.0   ball
# 4   231.0                NaN  5000000.0   ball

# %%
nba.College.fillna("NANANANANANA", inplace=True)

# %%
nba.head(10)
# Out:
#             Name            Team  Number GirlFriend Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0         PM       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0         PM       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0         PM       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0         PM       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0         PM       PF  29.0   6-10
# 5   Amir Johnson  Boston Celtics    90.0         PM       PF  29.0    6-9
# 6  Jordan Mickey  Boston Celtics    55.0         PM       PF  21.0    6-8
# 7   Kelly Olynyk  Boston Celtics    41.0         PM        C  25.0    7-0
# 8   Terry Rozier  Boston Celtics    12.0         PM       PG  22.0    6-2
# 9   Marcus Smart  Boston Celtics    36.0         PM       PG  22.0    6-4
#
#    Weight            College      Salary Sports
# 0   180.0              Texas   7730337.0   ball
# 1   235.0          Marquette   6796117.0   ball
# ...

# %%
nba.Salary = nba.Salary.astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 11 columns):
# Name          457 non-null object
# Team          457 non-null object
# Number        457 non-null float64
# GirlFriend    458 non-null object
# Position      457 non-null object
# Age           457 non-null float64
# Height        457 non-null object
# Weight        457 non-null float64
# College       458 non-null object
# Salary        458 non-null int64
# Sports        458 non-null object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 39.4+ KB

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["College"].nunique()
# Out:
# 119

# %%
nba.head()
# Out:
#             Name            Team  Number GirlFriend Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0         PM       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0         PM       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0         PM       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0         PM       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0         PM       PF  29.0   6-10
#
#    Weight            College   Salary Sports
# 0   180.0              Texas  7730337   ball
# 1   235.0          Marquette  6796117   ball
# 2   205.0  Boston University        0   ball
# 3   185.0      Georgia State  1148640   ball
# 4   231.0       NANANANANANA  5000000   ball

# %%
nba.sort_values(by="Name")
# Out:
#                     Name                    Team  Number GirlFriend Position  \
# 152         Aaron Brooks           Chicago Bulls     0.0         PM       PG
# 356         Aaron Gordon           Orlando Magic     0.0         PM       PF
# 328       Aaron Harrison       Charlotte Hornets     9.0         PM       SG
# 404        Adreian Payne  Minnesota Timberwolves    33.0         PM       PF
# 312           Al Horford           Atlanta Hawks    15.0         PM        C
# 330         Al Jefferson       Charlotte Hornets    25.0         PM        C
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0         PM       SF
# 368        Alan Anderson      Washington Wizards     6.0         PM       SG
# 135        Alan Williams            Phoenix Suns    15.0         PM        C
# 444           Alec Burks               Utah Jazz    10.0         PM       SG
# 128             Alex Len            Phoenix Suns    21.0         PM        C
# ...

# %%
nba.sort_values(by=["Team","Name"]).head()
# Out:
#                 Name           Team  Number GirlFriend Position   Age Height  \
# 312       Al Horford  Atlanta Hawks    15.0         PM        C  30.0   6-10
# 318  Dennis Schroder  Atlanta Hawks    17.0         PM       PG  22.0    6-1
# 323      Jeff Teague  Atlanta Hawks     0.0         PM       PG  27.0    6-2
# 309    Kent Bazemore  Atlanta Hawks    24.0         PM       SF  26.0    6-5
# 311     Kirk Hinrich  Atlanta Hawks    12.0         PM       SG  35.0    6-4
#
#      Weight       College    Salary Sports
# 312   245.0       Florida  12000000   ball
# 318   172.0  NANANANANANA   1763400   ball
# 323   186.0   Wake Forest   8000000   ball
# 309   201.0  Old Dominion   2000000   ball
# 311   190.0        Kansas   2854940   ball

# %%
nba.sort_values(by=["Team","Name"], ascending=[False,True], inplace=True)

# %%
nba.head()
# Out:
#                Name                Team  Number GirlFriend Position   Age  \
# 368   Alan Anderson  Washington Wizards     6.0         PM       SG  33.0
# 369    Bradley Beal  Washington Wizards     3.0         PM       SG  22.0
# 372     Drew Gooden  Washington Wizards    90.0         PM       PF  34.0
# 380  Garrett Temple  Washington Wizards    17.0         PM       SG  30.0
# 374      JJ Hickson  Washington Wizards    21.0         PM        C  27.0
#
#     Height  Weight               College   Salary Sports
# 368    6-6   220.0        Michigan State  4000000   ball
# 369    6-5   207.0               Florida  5694674   ball
# 372   6-10   250.0                Kansas  3300000   ball
# 380    6-6   195.0                   LSU  1100602   ball
# 374    6-9   242.0  North Carolina State   273038   ball

# %%
nba.sort_index()
# Out:
#                         Name                    Team  Number GirlFriend  \
# 0              Avery Bradley          Boston Celtics     0.0         PM
# 1                Jae Crowder          Boston Celtics    99.0         PM
# 2               John Holland          Boston Celtics    30.0         PM
# 3                R.J. Hunter          Boston Celtics    28.0         PM
# 4              Jonas Jerebko          Boston Celtics     8.0         PM
# 5               Amir Johnson          Boston Celtics    90.0         PM
# 6              Jordan Mickey          Boston Celtics    55.0         PM
# 7               Kelly Olynyk          Boston Celtics    41.0         PM
# 8               Terry Rozier          Boston Celtics    12.0         PM
# 9               Marcus Smart          Boston Celtics    36.0         PM
# 10           Jared Sullinger          Boston Celtics     7.0         PM
# 11             Isaiah Thomas          Boston Celtics     4.0         PM
# ...

# %%
nba['Salary Rank'] = nba['Salary'].rank(ascending=False).astype('int')

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337         97.0
# 1          Marquette  6796117        110.0
# 2  Boston University        0        452.0
# 3      Georgia State  1148640        322.0
# 4                NaN  5000000        147.0

# %%
nba.sort_values('Salary', ascending = False)
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# ...

# %%
nba = nba.dropna(how="all")

# %%
nba['Salary'] = nba['Salary'].fillna(0).astype('int')

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...
